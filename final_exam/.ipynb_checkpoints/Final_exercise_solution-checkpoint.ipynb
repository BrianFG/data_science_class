# %%
import pandas as pd

# %%
house_df = pd.read_csv('./kc_house_data.csv')

# %%
house_df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
bedrooms_6 = house_df.query('bedrooms == 6')['bathrooms']
bedrooms_7 = house_df.query('bedrooms == 7')['bathrooms']
bedrooms_5 = house_df.query('bedrooms == 5')['bathrooms']

# %%
bedrooms_6 = house_df.query('bedrooms == 6')['floors']
bedrooms_7 = house_df.query('bedrooms == 7')['floors']
bedrooms_5 = house_df.query('bedrooms == 5')['floors']

# %%
from scipy import stats
import statsmodels.api as sm

# %%
stats.ttest_ind(bedrooms_6, bedrooms_7)
# Out:
# Ttest_indResult(statistic=-3.0375607607930486, pvalue=0.0025890645760672463)

# %%
sm.stats.ttest_ind(bedrooms_6, bedrooms_7)
# Out:
# (-3.0375607607930486, 0.0025890645760672463, 308.0)

# %%
import scipy.stats as stats

# %%
stats.f_oneway(bedrooms_6, bedrooms_7, bedrooms_5)
# Out:
# F_onewayResult(statistic=1.8111906320053066, pvalue=0.16374032146882272)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scale_columns = ['yr_built', 'yr_renovated', 'zipcode', 'lat', 'long']
house_df[scale_columns] = scaler.fit_transform(house_df[scale_columns])

# %%
house_df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
from statsmodels.formula.api import ols

# %%
formula = f"""price ~ 
id +
bedrooms +
bathrooms +
sqft_living +
sqft_lot +
floors +
waterfront +
view +
condition +
grade +
sqft_above +
sqft_basement +
yr_built +
yr_renovated +
zipcode +
lat +
long +
sqft_living15 +
sqft_lot15"""
results = ols(formula, data=house_df).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     2797.
# Date:                Thu, 29 Jul 2021   Prob (F-statistic):               0.00
# Time:                        22:51:47   Log-Likelihood:            -2.9460e+05
# No. Observations:               21613   AIC:                         5.892e+05
# Df Residuals:                   21594   BIC:                         5.894e+05
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
house_df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# id              -0.016762
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
results.rsquared
# Out:
# 0.6998463505666739

# %%
results.params.sort_values()
# Out:
# Intercept       -628581.796293
# yr_built        -301559.004859
# long            -256202.266866
# zipcode         -115285.132441
# bedrooms         -35763.469829
# sqft_lot15           -0.396443
# id                   -0.000001
# sqft_lot              0.121836
# sqft_living15        21.625635
# sqft_basement        39.706796
# sqft_above           70.690224
# sqft_living         110.397023
# floors             6764.756286
# condition         26254.620059
# yr_renovated      39586.233072
# bathrooms         41155.689200
# view              53031.420726
# grade             96006.972647
# lat              374483.836000
# waterfront       582652.150069
# dtype: float64

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.feature_selection import RFE, f_regression

from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor

# %%
house_df = house_df.drop(['date', 'id'], axis=1)

# %%
numeric_columns = [column for column in house_df.columns if house_df[column].dtype in (int, float)]

# %%
numeric_df = house_df[numeric_columns]

# %%
house_df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
f, ax = plt.subplots(figsize=(16, 12))
plt.title('Pearson Correlation of features')
# Draw the heatmap using seaborn
#sns.heatmap(house_num.astype(float).corr(),linewidths=0.25,vmax=1.0, square=True, cmap="PuBuGn", linecolor='k', annot=True)
sns.heatmap(numeric_df.corr(),
            linewidths=0.25,
            vmax=1.0, 
            square=True, 
            #cmap="cubehelix", 
            linecolor='k', 
            annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of features'}>

# %%
for column in house_df.columns:
    results = ols(f"price ~ {column}", data=house_df).fit()
    print(column, results.rsquared)
    print(results.f_pvalue)
# Out:
# price 1.0
# 0.0
# bedrooms 0.0950794746765764
# 0.0
# bathrooms 0.27576939959239877
# 0.0
# sqft_living 0.4928532179037931
# 0.0
# sqft_lot 0.0080390699212195
# 7.972504510326147e-40
# floors 0.06594310068341103
# 1.6e-322
# waterfront 0.07095267538578331
# 0.0
# view 0.15784211584121544
# 0.0
# condition 0.0013221797086617748
# 8.935654062331967e-08
# grade 0.44546848610928713
# 0.0
# sqft_above 0.36671175283827917
# 0.0
# sqft_basement 0.104856815269744
# 0.0
# yr_built 0.002917245534413082
# 1.929872809374955e-15
# yr_renovated 0.015985504123854355
# 1.0213478858043326e-77
# zipcode 0.0028305437054875204
# 5.011050503392573e-15
# lat 0.0942511367291744
# 0.0
# long 0.00046769430149007363
# 0.0014750922063201787
# sqft_living15 0.342668460756017
# 0.0
# sqft_lot15 0.006797532958571217
# 6.4175598893496985e-34

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = house_df.drop(['price'], axis=1)

# %%
y = house_df['price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=40)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.698935541005893
