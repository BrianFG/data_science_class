# %%
import pandas as pd
import datetime

# %%
salaries_df = pd.read_csv('salaries.csv')

# %%
salaries_df['from_date'] = pd.to_datetime(salaries_df['from_date'])

# %%
salaries_df.head(3)
# Out:
#    emp_no  salary  from_date     to_date  birth_date first_name last_name  \
# 0   10001   60117 1986-06-26  1987-06-26  1953-09-02     Georgi   Facello
# 1   10001   62102 1987-06-26  1988-06-25  1953-09-02     Georgi   Facello
# 2   10001   66074 1988-06-25  1989-06-25  1953-09-02     Georgi   Facello
#
#   gender   hire_date
# 0      M  1986-06-26
# 1      M  1986-06-26
# 2      M  1986-06-26

# %% [markdown]
# ## Filtering

# %% [markdown]
# Salaries with `from_date` > than year 2000 and `first_name` starts with G

# %%
my_filter = ((salaries_df['from_date'] > datetime.datetime(2000,1,1)) &
              salaries_df['first_name'].str.contains("^G"))
salaries_df[my_filter]
# Out:
#      emp_no  salary  from_date     to_date  birth_date first_name  last_name  \
# 14    10001   85112 2000-06-22  2001-06-22  1953-09-02     Georgi    Facello
# 15    10001   85097 2001-06-22  2002-06-22  1953-09-02     Georgi    Facello
# 16    10001   88958 2002-06-22  9999-01-01  1953-09-02     Georgi    Facello
# 621   10063   71028 2000-04-05  2001-04-05  1952-08-06       Gino  Leonhardt
# 622   10063   73393 2001-04-05  2002-04-04  1952-08-06       Gino  Leonhardt
# 623   10063   74841 2002-04-04  9999-01-01  1952-08-06       Gino  Leonhardt
# 758   10075   67492 2000-05-14  2001-01-15  1960-03-09        Gao   Dolinsky
#
#     gender   hire_date
# 14       M  1986-06-26
# 15       M  1986-06-26
# 16       M  1986-06-26
# 621      F  1989-04-08
# 622      F  1989-04-08
# 623      F  1989-04-08
# 758      F  1987-03-19

# %% [markdown]
# For simple filtering, `query()` function can be used

# %%
salaries_df.query("salary > 110000")
# Out:
#      emp_no  salary  from_date     to_date  birth_date first_name last_name  \
# 681   10068  111623 1999-08-04  2000-08-03  1962-11-26   Charlene   Brattka
# 682   10068  112470 2000-08-03  2001-08-03  1962-11-26   Charlene   Brattka
# 683   10068  113229 2001-08-03  9999-01-01  1962-11-26   Charlene   Brattka
#
#     gender   hire_date
# 681      M  1987-08-07
# 682      M  1987-08-07
# 683      M  1987-08-07

# %% [markdown]
# ## Replace
# #### There are many way of replace, we will cover some of them

# %% [markdown]
# - `replace(str, str)`
#
#     - Replace any value that is equual to Georgi with georgi

# %%
salaries_df.replace('Georgi', 'georgi').head()
# Out:
#    emp_no  salary  from_date     to_date  birth_date first_name last_name  \
# 0   10001   60117 1986-06-26  1987-06-26  1953-09-02     georgi   Facello
# 1   10001   62102 1987-06-26  1988-06-25  1953-09-02     georgi   Facello
# 2   10001   66074 1988-06-25  1989-06-25  1953-09-02     georgi   Facello
# 3   10001   66596 1989-06-25  1990-06-25  1953-09-02     georgi   Facello
# 4   10001   66961 1990-06-25  1991-06-25  1953-09-02     georgi   Facello
#
#   gender   hire_date
# 0      M  1986-06-26
# 1      M  1986-06-26
# 2      M  1986-06-26
# 3      M  1986-06-26
# 4      M  1986-06-26

# %% [markdown]
# - `replace(regex, regex)`
#     - Replacing strings with two consecutive vowels, with the string "two vowels"

# %%
salaries_df.replace(r'^.+[aeiou]{2}.*$',  'two vowels', regex=True)
# Out:
#      emp_no  salary  from_date     to_date  birth_date  first_name  last_name  \
# 0     10001   60117 1986-06-26  1987-06-26  1953-09-02  two vowels    Facello
# 1     10001   62102 1987-06-26  1988-06-25  1953-09-02  two vowels    Facello
# 2     10001   66074 1988-06-25  1989-06-25  1953-09-02  two vowels    Facello
# 3     10001   66596 1989-06-25  1990-06-25  1953-09-02  two vowels    Facello
# 4     10001   66961 1990-06-25  1991-06-25  1953-09-02  two vowels    Facello
# ..      ...     ...        ...         ...         ...         ...        ...
# 995   10100   70464 1998-09-18  1999-09-18  1953-04-21    Hironobu  Haraldson
# 996   10100   72343 1999-09-18  2000-09-17  1953-04-21    Hironobu  Haraldson
# 997   10100   74365 2000-09-17  2001-09-17  1953-04-21    Hironobu  Haraldson
# 998   10100   74957 2001-09-17  9999-01-01  1953-04-21    Hironobu  Haraldson
# 999   10101   66591 1998-10-14  1999-10-14  1952-04-15       Perla     Heyers
#
#     gender   hire_date
# 0        M  1986-06-26
# 1        M  1986-06-26
# 2        M  1986-06-26
# 3        M  1986-06-26
# 4        M  1986-06-26
# ..     ...         ...
# 995      F  1987-09-21
# 996      F  1987-09-21
# 997      F  1987-09-21
# 998      F  1987-09-21
# 999      F  1992-12-28
#
# [1000 rows x 9 columns]

# %%
s = salaries_df.replace({'last_name': r'^.+[^aeiou]{2}.*$'}, {'first_name': 'NEW'}, regex=True)

# %%
s
# Out:
#      emp_no  salary  from_date     to_date  birth_date first_name  last_name  \
# 0     10001   60117 1986-06-26  1987-06-26  1953-09-02     Georgi    Facello
# 1     10001   62102 1987-06-26  1988-06-25  1953-09-02     Georgi    Facello
# 2     10001   66074 1988-06-25  1989-06-25  1953-09-02     Georgi    Facello
# 3     10001   66596 1989-06-25  1990-06-25  1953-09-02     Georgi    Facello
# 4     10001   66961 1990-06-25  1991-06-25  1953-09-02     Georgi    Facello
# ..      ...     ...        ...         ...         ...        ...        ...
# 995   10100   70464 1998-09-18  1999-09-18  1953-04-21   Hironobu  Haraldson
# 996   10100   72343 1999-09-18  2000-09-17  1953-04-21   Hironobu  Haraldson
# 997   10100   74365 2000-09-17  2001-09-17  1953-04-21   Hironobu  Haraldson
# 998   10100   74957 2001-09-17  9999-01-01  1953-04-21   Hironobu  Haraldson
# 999   10101   66591 1998-10-14  1999-10-14  1952-04-15      Perla     Heyers
#
#     gender   hire_date
# 0        M  1986-06-26
# 1        M  1986-06-26
# 2        M  1986-06-26
# 3        M  1986-06-26
# 4        M  1986-06-26
# ..     ...         ...
# 995      F  1987-09-21
# 996      F  1987-09-21
# 997      F  1987-09-21
# 998      F  1987-09-21
# 999      F  1992-12-28
#
# [1000 rows x 9 columns]

# %%
s[s.first_name == 'NEW']
# Out:
# Empty DataFrame
# Columns: [emp_no, salary, from_date, to_date, birth_date, first_name, last_name, gender, hire_date]
# Index: []

# %%
datetime.date(2000,1,1)
# Out:
# datetime.date(2000, 1, 1)

# %%
salaries_df['from_date']
# Out:
# 0      1986-06-26
# 1      1987-06-26
# 2      1988-06-25
# 3      1989-06-25
# 4      1990-06-25
#           ...
# 995    1998-09-18
# 996    1999-09-18
# 997    2000-09-17
# 998    2001-09-17
# 999    1998-10-14
# Name: from_date, Length: 1000, dtype: object
